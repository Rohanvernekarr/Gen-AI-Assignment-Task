# %% [markdown]
# Answer the following questions in your own words:
#
# 1. What is the difference between "Love" and "love" in NLP?
# 2. What happens if stopwords are not removed?
# 3. Provide two real-world scenarios where removing stopwords can be harmful.
# 4. Explain the difference between stemming and lemmatization.
#
#
# Answers:
#
# 1. Love and love are treated as two different tokens because one starts with a capital letter and the other does not. Tyhe model gives different ascii values
#
# ...
#
# 2. If stopwords are not removed then
#
#    a. The dataset becomes larger and noisy and reduce model accuracy
#
#    b. Training becomes slower because there are too many unnecessary tokens.
#
#    ...
#
# 3. In a. Sentiment analysis stopword like " not " can completely change the meaning of sentence
#
#    ex -  "I do not like this product"
#
#    If "not" is removed:
#
#           "I do like this product"
#
#    This changes negative sentiment into positive sentiment, which is incorrect.
#
#    b. Question Answering system
#
#    Stopwords can be important in understanding questions.
#
#    Example:    "What is the capital of India?"
#
#       If stopwords are removed:
#
#               "capital India"
#
#       The structure and meaning of the question is lost, making it harder for the system to answer correctly.
#
#       ....
#
# 4. Stemming reduces tye word and brings them in their exact meaning  like word endings, prefix and suffix.
#   studies - studi
#
#    Lemmatization converts a word to its actual dictionary root form
#
#    better - good
